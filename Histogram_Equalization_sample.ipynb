# %% [markdown]
# <a href="https://colab.research.google.com/github/RuthKassahun/Skin-Lesion-Classification/blob/main/Histogram_Equalization_sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import os
from pylab import *

# %%
src = cv2.imread('/content/nev00043.jpg')
plt.imshow(cv2.cvtColor(src, cv2.COLOR_BGR2RGB), interpolation='nearest')

# %%
src = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)

# %%
dst = cv2.equalizeHist(src)
plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB), interpolation='nearest')
